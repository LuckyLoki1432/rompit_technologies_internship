# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df_stock = pd.read_csv('/content/drive/MyDrive/infolimpioavanzadoTarget.csv')
df_stock.head()
# Out:
#          date       open       high        low      close   adjclose  volume  \
# 0  2022-01-03  17.799999  18.219000  17.500000  17.760000  17.760000  106600
# 1  2022-01-04  17.700001  18.309999  17.620001  17.660000  17.660000  128700
# 2  2022-01-05  17.580000  17.799999  16.910000  16.950001  16.950001  103100
# 3  2022-01-06  16.650000  16.879999  16.139999  16.170000  16.170000  173600
# 4  2022-01-07  16.219999  16.290001  15.630000  15.710000  15.710000  137800
#
#   ticker  RSIadjclose15  RSIvolume15  ...  high-15  K-15  D-15  \
# 0   ASLE            NaN          NaN  ...      NaN   NaN   NaN
# 1   ASLE            NaN          NaN  ...      NaN   NaN   NaN
# 2   ASLE            NaN          NaN  ...      NaN   NaN   NaN
# 3   ASLE            NaN          NaN  ...      NaN   NaN   NaN
# 4   ASLE            NaN          NaN  ...      NaN   NaN   NaN
#
#    stochastic-k-15  stochastic-d-15  stochastic-kd-15  volumenrelativo  \
# ...

# %%
df_stock.shape
# Out:
# (7781, 1285)
# (7781, 1285)

# %%
df_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7781 entries, 0 to 7780
# Columns: 1285 entries, date to TARGET
# dtypes: float64(1280), int64(3), object(2)
# memory usage: 76.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7781 entries, 0 to 7780
# Columns: 1285 entries, date to TARGET
# dtypes: float64(1280), int64(3), object(2)
# memory usage: 76.3+ MB

# %%
df_stock.describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# ...

# %%
df_stock.isnull().sum()
# Out:
# date                  0
# open                  0
# high                  0
# low                   0
# close                 0
#                    ...
# stochastic-kd-15    587
# volumenrelativo     215
# diff                155
# INCREMENTO          155
# TARGET                0
# Length: 1285, dtype: int64
# date                  0
# open                  0
# high                  0
# low                   0
# close                 0
#                    ...
# stochastic-kd-15    587
# volumenrelativo     215
# diff                155
# INCREMENTO          155
# TARGET                0
# Length: 1285, dtype: int64

# %%
data_new = df_stock[['date','open', 'high', 'low', 'close']]
data_new
# Out:
#             date       open       high        low      close
# 0     2022-01-03  17.799999  18.219000  17.500000  17.760000
# 1     2022-01-04  17.700001  18.309999  17.620001  17.660000
# 2     2022-01-05  17.580000  17.799999  16.910000  16.950001
# 3     2022-01-06  16.650000  16.879999  16.139999  16.170000
# 4     2022-01-07  16.219999  16.290001  15.630000  15.710000
# ...          ...        ...        ...        ...        ...
# 7776  2022-12-23  23.250000  23.540001  23.250000  23.290001
# 7777  2022-12-27  23.350000  23.610001  23.250000  23.350000
# 7778  2022-12-28  23.450001  23.570000  23.219999  23.350000
# 7779  2022-12-29  23.330000  23.740000  23.330000  23.610001
# 7780  2022-12-30  23.680000  23.760000  23.610001  23.610001
#
# [7781 rows x 5 columns]
#             date       open       high        low      close
# 0     2022-01-03  17.799999  18.219000  17.500000  17.760000
# 1     2022-01-04  17.700001  18.309999  17.620001  17.660000
# ...

# %%
data_new.isnull().sum()
# Out:
# date     0
# open     0
# high     0
# low      0
# close    0
# dtype: int64
# date     0
# open     0
# high     0
# low      0
# close    0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data_new["tomorrow"]= data_new["close"].shift(-1)
data_new
# Out:
# <ipython-input-14-5314dd1e6995>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_new["tomorrow"]= data_new["close"].shift(-1)
#             date       open       high        low      close   tomorrow
# 0     2022-01-03  17.799999  18.219000  17.500000  17.760000  17.660000
# 1     2022-01-04  17.700001  18.309999  17.620001  17.660000  16.950001
# 2     2022-01-05  17.580000  17.799999  16.910000  16.950001  16.170000
# 3     2022-01-06  16.650000  16.879999  16.139999  16.170000  15.710000
# 4     2022-01-07  16.219999  16.290001  15.630000  15.710000  15.860000
# ...          ...        ...        ...        ...        ...        ...
# 7776  2022-12-23  23.250000  23.540001  23.250000  23.290001  23.350000
# ...

# %%
data_new["target"] = data_new["tomorrow"] > data_new["close"].astype(float)
data_new
# Out:
# <ipython-input-15-5425aff5bc51>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_new["target"] = data_new["tomorrow"] > data_new["close"].astype(float)
#             date       open       high        low      close   tomorrow  \
# 0     2022-01-03  17.799999  18.219000  17.500000  17.760000  17.660000
# 1     2022-01-04  17.700001  18.309999  17.620001  17.660000  16.950001
# 2     2022-01-05  17.580000  17.799999  16.910000  16.950001  16.170000
# 3     2022-01-06  16.650000  16.879999  16.139999  16.170000  15.710000
# 4     2022-01-07  16.219999  16.290001  15.630000  15.710000  15.860000
# ...          ...        ...        ...        ...        ...        ...
# ...

# %%
df=data_new

# %%
df.head()
# Out:
#          date       open       high        low      close   tomorrow  target
# 0  2022-01-03  17.799999  18.219000  17.500000  17.760000  17.660000   False
# 1  2022-01-04  17.700001  18.309999  17.620001  17.660000  16.950001   False
# 2  2022-01-05  17.580000  17.799999  16.910000  16.950001  16.170000   False
# 3  2022-01-06  16.650000  16.879999  16.139999  16.170000  15.710000   False
# 4  2022-01-07  16.219999  16.290001  15.630000  15.710000  15.860000    True
#          date       open       high        low      close   tomorrow  target
# 0  2022-01-03  17.799999  18.219000  17.500000  17.760000  17.660000   False
# 1  2022-01-04  17.700001  18.309999  17.620001  17.660000  16.950001   False
# 2  2022-01-05  17.580000  17.799999  16.910000  16.950001  16.170000   False
# 3  2022-01-06  16.650000  16.879999  16.139999  16.170000  15.710000   False
# 4  2022-01-07  16.219999  16.290001  15.630000  15.710000  15.860000    True

# %%
df['profit_change'] = df['target'] - df['close']
# Out:
# <ipython-input-18-feb09b323b64>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['profit_change'] = df['target'] - df['close']
# <ipython-input-37-feb09b323b64>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['profit_change'] = df['target'] - df['close']

# %%
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(12, 6))

# Plot the stock price changes (open, high, low, close)
plt.plot(df['date'], df['open'], label='Open', color='blue', alpha=0.7)
plt.plot(df['date'], df['high'], label='High', color='green', alpha=0.7)
plt.plot(df['date'], df['low'], label='Low', color='red', alpha=0.7)
plt.plot(df['date'], df['close'], label='Close', color='black', alpha=0.7)

# Plot the profit change
plt.plot(df['date'], df['profit_change'], label='Profit Change', color='orange', alpha=0.7, linestyle='--')

# Formatting
plt.xlabel('Date')
plt.ylabel('Price / Profit Change')
plt.title('Stock Price Changes and Profit Change over Time')
plt.xticks(rotation=45)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample data to display a limited number of points (e.g., every 10th date)
sample_interval = 10
df_sampled = df.iloc[::sample_interval]

# Set the figure size
plt.figure(figsize=(12, 6))

# Plot the stock price changes (open, high, low, close)
plt.plot(df_sampled['date'], df_sampled['open'], label='Open', color='blue', alpha=0.7)
plt.plot(df_sampled['date'], df_sampled['high'], label='High', color='green', alpha=0.7)
plt.plot(df_sampled['date'], df_sampled['low'], label='Low', color='red', alpha=0.7)
plt.plot(df_sampled['date'], df_sampled['close'], label='Close', color='black', alpha=0.7)

# Plot the profit change
plt.plot(df_sampled['date'], df_sampled['profit_change'], label='Profit Change', color='orange', alpha=0.7, linestyle='--')

# Formatting the x-axis date labels to make them more readable
plt.xticks(rotation=45)
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d'))

# Formatting
plt.xlabel('Date')
plt.ylabel('Price / Profit Change')
plt.title('Stock Price Changes and Profit Change over Time')
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt

# Sample data
df = pd.read_csv('/content/drive/MyDrive/infolimpioavanzadoTarget.csv')  # Load your dataset

# Data Preprocessing: Shift the "close" price to create the target (Next day's price)
df['next_day_close'] = df['close'].shift(-1)

# Drop the last row because it will have NaN in 'next_day_close'
df = df.dropna()

# Define features (X) and target (y)
X = df[['open', 'high', 'low', 'close']]  # You can add more features here
y = df['next_day_close']

# Split the data into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Model: Random Forest Regressor
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error (MAE): {mae}')

# Plot the true vs predicted prices for visual comparison
plt.figure(figsize=(12, 6))
plt.plot(y_test.index, y_test, label='True Prices', color='blue')
plt.plot(y_test.index, y_pred, label='Predicted Prices', color='red', linestyle='--')
plt.title('True vs Predicted Next Day Stock Price')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# Mean Absolute Error (MAE): 0.5312277959707091
# Mean Absolute Error (MAE): 0.5312277959707091

# %%
def predict_future_stock_price(model, last_data, days_ahead):
    # Initialize an empty list to store predictions
    predictions = []

    # Current data point to predict from (last known data point)
    current_data = last_data.copy()

    for _ in range(days_ahead):
        # Make the prediction for the next day
        next_day_price = model.predict([current_data])[0]
        predictions.append(next_day_price)

        # Update current data for the next prediction by using predicted 'next_day_close'
        # Use the previous predicted value as the 'close' for the next day's prediction
        current_data = np.array([current_data[0], current_data[1], current_data[2], next_day_price])  # Open, High, Low, Predicted Close

    return predictions

# Define the last data point (use the last row of the data)
last_data = df[['open', 'high', 'low', 'close']].iloc[-1].values

# Define how many days ahead you want to predict
days_ahead = 10

# Get predictions for the next 'days_ahead' days
future_prices = predict_future_stock_price(model, last_data, days_ahead)

# Print out predicted prices for the next 10 days
print("Predicted stock prices for the next 10 days:")
for i, price in enumerate(future_prices, 1):
    print(f"Day {i}: {price}")
# Out:
# Predicted stock prices for the next 10 days:
# Day 1: 23.328839778900146
# Day 2: 23.36283975601196
# Day 3: 23.384059734344483
# Day 4: 23.385059719085692
# Day 5: 23.385059719085692
# Day 6: 23.385059719085692
# Day 7: 23.385059719085692
# Day 8: 23.385059719085692
# Day 9: 23.385059719085692
# Day 10: 23.385059719085692
# Predicted stock prices for the next 10 days:
# Day 1: 23.328839778900146
# Day 2: 23.36283975601196
# Day 3: 23.384059734344483
# Day 4: 23.385059719085692
# Day 5: 23.385059719085692
# Day 6: 23.385059719085692
# Day 7: 23.385059719085692
# Day 8: 23.385059719085692
# Day 9: 23.385059719085692
# Day 10: 23.385059719085692

# %%
import warnings

# Suppress the specific warning
warnings.filterwarnings("ignore", message=".*does not have valid feature names.*")

def predict_specific_day_stock_price(model, last_data, days_ahead):
    """
    Predict the stock price for a specific day ahead based on the current day's data.
    model: The trained model
    last_data: The most recent stock data (e.g., the last row of your dataset)
    days_ahead: The number of days in the future for which to predict the stock price
    """
    # Initialize current data for prediction
    current_data = last_data.copy()

    # To predict a specific day ahead, simply repeat prediction steps
    for _ in range(days_ahead):
        # Predict for the next day using the current day's data
        next_day_price = model.predict([current_data])[0]

        # Update current data for the next prediction (just using predicted 'close' for next day)
        current_data = np.array([current_data[0], current_data[1], current_data[2], next_day_price])

    return next_day_price

# Define the last data point (use the last row of the data)
last_data = df[['open', 'high', 'low', 'close']].iloc[-1].values

# Input: How many days ahead do you want to predict?
days_ahead = int(input("Enter the number of days ahead you want to predict the stock price: "))

# Get the stock price prediction for that specific day
predicted_price = predict_specific_day_stock_price(model, last_data, days_ahead)

# Output the predicted price for the entered number of days ahead
print(f"Predicted stock price for day {days_ahead}: {predicted_price}")
# Out:
# Enter the number of days ahead you want to predict the stock price: 1000
# Predicted stock price for day 1000: 23.385059719085692
# Enter the number of days ahead you want to predict the stock price: 2000
# Predicted stock price for day 2000: 23.385059719085692

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Load your stock price data (replace this with your actual data source)
df = pd.read_csv('/content/drive/MyDrive/infolimpioavanzadoTarget.csv')  # Ensure your data has 'open', 'high', 'low', 'close'

# Select 'close' prices for simplicity (you can use others like open, high, low)
data = df['close'].values.reshape(-1, 1)

# Scale the data (LSTM models work better with normalized data)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Prepare the data for the LSTM (create sequences)
def create_sequences(data, seq_length):
    x = []
    y = []
    for i in range(seq_length, len(data)):
        x.append(data[i-seq_length:i, 0])  # Sequence of previous 'seq_length' days
        y.append(data[i, 0])  # The target value is the price on the next day
    return np.array(x), np.array(y)

# Set the sequence length
seq_length = 60  # Use the past 60 days to predict the next day

# Create sequences
x, y = create_sequences(scaled_data, seq_length)

# Split into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, shuffle=False)

# Reshape input data for LSTM (samples, time steps, features)
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# Build the LSTM model
model = Sequential()

model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))  # Add dropout to prevent overfitting

model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(units=1))  # Output layer for regression (next day's stock price)

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32)

# Predicting the stock prices for the test set
predictions = model.predict(x_test)

# Inverse transform the predictions and test data to get actual prices
predictions = scaler.inverse_transform(predictions)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plotting the results
plt.plot(y_test_actual, color='blue', label='Actual Stock Price')
plt.plot(predictions, color='red', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# Example: Predicting the next day's price based on the last 'seq_length' days
last_data = scaled_data[-seq_length:]
last_data = last_data.reshape((1, seq_length, 1))

next_day_price = model.predict(last_data)
next_day_price = scaler.inverse_transform(next_day_price)

print(f"Predicted stock price for the next day: {next_day_price[0][0]}")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 16s 66ms/step - loss: 0.0036
# Epoch 2/10
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 20s 64ms/step - loss: 9.7443e-04
# Epoch 3/10
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - loss: 6.0518e-04
# Epoch 4/10
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 20s 68ms/step - loss: 6.5679e-04
# Epoch 5/10
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 18s 54ms/step - loss: 6.6139e-04
# Epoch 6/10
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - loss: 6.5556e-04
# Epoch 7/10
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 21s 62ms/step - loss: 6.6267e-04
# Epoch 8/10
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - loss: 9.4535e-04
# Epoch 9/10
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - loss: 6.5431e-04
# Epoch 10/10
# ...

# %%
from tensorflow.keras.layers import Bidirectional

model = Sequential()
model.add(Bidirectional(LSTM(units=50, return_sequences=True), input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(units=50, return_sequences=False)))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# %%
from tensorflow.keras.optimizers import Adam
model.compile(optimizer=Adam(learning_rate=0.0001), loss='mean_squared_error')

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 31s 129ms/step - loss: 0.0079 - val_loss: 5.4550e-05
# Epoch 2/50
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 36s 106ms/step - loss: 0.0017 - val_loss: 3.7205e-05
# Epoch 3/50
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 23s 118ms/step - loss: 0.0011 - val_loss: 5.6927e-05
# Epoch 4/50
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 38s 105ms/step - loss: 0.0011 - val_loss: 3.2759e-05
# Epoch 5/50
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 23s 118ms/step - loss: 9.7389e-04 - val_loss: 2.1493e-05
# Epoch 6/50
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 38s 104ms/step - loss: 8.3008e-04 - val_loss: 3.3384e-05
# Epoch 7/50
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 23s 116ms/step - loss: 7.9967e-04 - val_loss: 1.8883e-05
# Epoch 8/50
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - loss: 9.8969e-04 - val_loss: 2.2461e-05
# Epoch 9/50
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - loss: 8.4339e-04 - val_loss: 2.1539e-05
# Epoch 10/50
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 41s 106ms/step - loss: 7.3437e-04 - val_loss: 1.6167e-05
# ...
